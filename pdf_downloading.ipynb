# %% [markdown]
# ## Attempt to download all pdfs found in the list of urls.
# ### Only about 15% are downloaded successfully. This is due to the parser being unable to find the PDF link on the page.

# %%
import pandas as pd
import requests
import os
import time
from bs4 import BeautifulSoup
from urllib.parse import urlparse

# === CONFIGURATION ===
input_csv = "datasets\open_access_enriched.csv"      # your enriched file
url_column = "Open Access URL"              # name of column with links
doi_column = "DOI"                          # name of DOI column (for filename)
pdf_folder = "papers_1"

# === SETUP ===
os.makedirs(pdf_folder, exist_ok=True)
df = pd.read_csv(input_csv)
success_count = 0
fail_count = 0

def try_download_pdf(doi, url):
    filename = os.path.join(pdf_folder, doi.replace("/", "_") + ".pdf")
    headers = {
        "User-Agent": "Mozilla/5.0"
    }

    try:
        if pd.isna(url):
            return False

        # Direct PDF
        if url.endswith(".pdf"):
            r = requests.get(url, headers=headers)
            if r.status_code == 200:
                with open(filename, "wb") as f:
                    f.write(r.content)
                return True

        # Scrape page for PDF links
        r = requests.get(url, headers=headers, timeout=10)
        soup = BeautifulSoup(r.text, "html.parser")
        pdf_links = [a['href'] for a in soup.find_all('a', href=True) if "pdf" in a['href'].lower()]
        for link in pdf_links:
            full_link = link if link.startswith("http") else f"{urlparse(url).scheme}://{urlparse(url).netloc}{link}"
            r_pdf = requests.get(full_link, headers=headers)
            if r_pdf.status_code == 200:
                with open(filename, "wb") as f:
                    f.write(r_pdf.content)
                return True
    except Exception as e:
        return False

    return False

# === MAIN LOOP ===
for i, row in df.iterrows():
    doi = str(row[doi_column])
    url = row[url_column]
    success = try_download_pdf(doi, url)

    if success:
        success_count += 1
    else:
        fail_count += 1

    if (i + 1) % 10 == 0:
        print(f"Processed {i+1}/{len(df)} — ✅ {success_count} downloaded | ❌ {fail_count} failed")

print(f"\n🎉 Done! PDFs saved in folder: {pdf_folder}")
print(f"✅ Total successful: {success_count}")
print(f"❌ Total failed: {fail_count}")
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\o'
# <>:9: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\jackp\AppData\Local\Temp\ipykernel_10160\219843431.py:9: SyntaxWarning: invalid escape sequence '\o'
#   input_csv = "datasets\open_access_enriched.csv"      # your enriched file
# Processed 10/1499 — ✅ 1 downloaded | ❌ 9 failed
# Processed 20/1499 — ✅ 2 downloaded | ❌ 18 failed
# Processed 30/1499 — ✅ 3 downloaded | ❌ 27 failed
# Processed 40/1499 — ✅ 3 downloaded | ❌ 37 failed
# Processed 50/1499 — ✅ 5 downloaded | ❌ 45 failed
# Processed 60/1499 — ✅ 5 downloaded | ❌ 55 failed
# Processed 70/1499 — ✅ 7 downloaded | ❌ 63 failed
# Processed 80/1499 — ✅ 8 downloaded | ❌ 72 failed
# Processed 90/1499 — ✅ 11 downloaded | ❌ 79 failed
# Processed 100/1499 — ✅ 13 downloaded | ❌ 87 failed
# Processed 110/1499 — ✅ 15 downloaded | ❌ 95 failed
# Processed 120/1499 — ✅ 17 downloaded | ❌ 103 failed
# Processed 130/1499 — ✅ 18 downloaded | ❌ 112 failed
# Processed 140/1499 — ✅ 18 downloaded | ❌ 122 failed
# Processed 150/1499 — ✅ 18 downloaded | ❌ 132 failed
# Processed 160/1499 — ✅ 19 downloaded | ❌ 141 failed
# Processed 170/1499 — ✅ 21 downloaded | ❌ 149 failed
# Processed 180/1499 — ✅ 21 downloaded | ❌ 159 failed
# Processed 190/1499 — ✅ 24 downloaded | ❌ 166 failed
# Processed 200/1499 — ✅ 27 downloaded | ❌ 173 failed
# Processed 210/1499 — ✅ 29 downloaded | ❌ 181 failed
# Processed 220/1499 — ✅ 31 downloaded | ❌ 189 failed
# Processed 230/1499 — ✅ 32 downloaded | ❌ 198 failed
# Processed 240/1499 — ✅ 33 downloaded | ❌ 207 failed
# Processed 250/1499 — ✅ 35 downloaded | ❌ 215 failed
# Processed 260/1499 — ✅ 35 downloaded | ❌ 225 failed
# Processed 270/1499 — ✅ 38 downloaded | ❌ 232 failed
# Processed 280/1499 — ✅ 39 downloaded | ❌ 241 failed
# Processed 290/1499 — ✅ 39 downloaded | ❌ 251 failed
# Processed 300/1499 — ✅ 39 downloaded | ❌ 261 failed
# Processed 310/1499 — ✅ 40 downloaded | ❌ 270 failed
# Processed 320/1499 — ✅ 41 downloaded | ❌ 279 failed
# Processed 330/1499 — ✅ 43 downloaded | ❌ 287 failed
# Processed 340/1499 — ✅ 45 downloaded | ❌ 295 failed
# Processed 350/1499 — ✅ 45 downloaded | ❌ 305 failed
# Processed 360/1499 — ✅ 46 downloaded | ❌ 314 failed
# Processed 370/1499 — ✅ 49 downloaded | ❌ 321 failed
# Processed 380/1499 — ✅ 49 downloaded | ❌ 331 failed
# Processed 390/1499 — ✅ 50 downloaded | ❌ 340 failed
# Processed 400/1499 — ✅ 51 downloaded | ❌ 349 failed
# Processed 410/1499 — ✅ 53 downloaded | ❌ 357 failed
# Processed 420/1499 — ✅ 53 downloaded | ❌ 367 failed
# Processed 430/1499 — ✅ 54 downloaded | ❌ 376 failed
# Processed 440/1499 — ✅ 54 downloaded | ❌ 386 failed
# Processed 450/1499 — ✅ 55 downloaded | ❌ 395 failed
# Processed 460/1499 — ✅ 56 downloaded | ❌ 404 failed
# Processed 470/1499 — ✅ 57 downloaded | ❌ 413 failed
# Processed 480/1499 — ✅ 58 downloaded | ❌ 422 failed
# Processed 490/1499 — ✅ 59 downloaded | ❌ 431 failed
# Processed 500/1499 — ✅ 61 downloaded | ❌ 439 failed
# Processed 510/1499 — ✅ 65 downloaded | ❌ 445 failed
# Processed 520/1499 — ✅ 66 downloaded | ❌ 454 failed
# Processed 530/1499 — ✅ 70 downloaded | ❌ 460 failed
# Processed 540/1499 — ✅ 71 downloaded | ❌ 469 failed
# Processed 550/1499 — ✅ 72 downloaded | ❌ 478 failed
# Processed 560/1499 — ✅ 74 downloaded | ❌ 486 failed
# Processed 570/1499 — ✅ 74 downloaded | ❌ 496 failed
# Processed 580/1499 — ✅ 75 downloaded | ❌ 505 failed
# Processed 590/1499 — ✅ 77 downloaded | ❌ 513 failed
# Processed 600/1499 — ✅ 78 downloaded | ❌ 522 failed
# Processed 610/1499 — ✅ 78 downloaded | ❌ 532 failed
# Processed 620/1499 — ✅ 79 downloaded | ❌ 541 failed
# Processed 630/1499 — ✅ 79 downloaded | ❌ 551 failed
# Processed 640/1499 — ✅ 81 downloaded | ❌ 559 failed
# Processed 650/1499 — ✅ 84 downloaded | ❌ 566 failed
# Processed 660/1499 — ✅ 85 downloaded | ❌ 575 failed
# Processed 670/1499 — ✅ 85 downloaded | ❌ 585 failed
# Processed 680/1499 — ✅ 86 downloaded | ❌ 594 failed
# Processed 690/1499 — ✅ 87 downloaded | ❌ 603 failed
# Processed 700/1499 — ✅ 90 downloaded | ❌ 610 failed
# Processed 710/1499 — ✅ 92 downloaded | ❌ 618 failed
# Processed 720/1499 — ✅ 93 downloaded | ❌ 627 failed
# Processed 730/1499 — ✅ 94 downloaded | ❌ 636 failed
# Processed 740/1499 — ✅ 95 downloaded | ❌ 645 failed
# Processed 750/1499 — ✅ 98 downloaded | ❌ 652 failed
# Processed 760/1499 — ✅ 102 downloaded | ❌ 658 failed
# Processed 770/1499 — ✅ 102 downloaded | ❌ 668 failed
# Processed 780/1499 — ✅ 102 downloaded | ❌ 678 failed
# Processed 790/1499 — ✅ 105 downloaded | ❌ 685 failed
# Processed 800/1499 — ✅ 105 downloaded | ❌ 695 failed
# Processed 810/1499 — ✅ 106 downloaded | ❌ 704 failed
# Processed 820/1499 — ✅ 107 downloaded | ❌ 713 failed
# Processed 830/1499 — ✅ 109 downloaded | ❌ 721 failed
# Processed 840/1499 — ✅ 110 downloaded | ❌ 730 failed
# Processed 850/1499 — ✅ 112 downloaded | ❌ 738 failed
# Processed 860/1499 — ✅ 114 downloaded | ❌ 746 failed
# Processed 870/1499 — ✅ 114 downloaded | ❌ 756 failed
# Processed 880/1499 — ✅ 115 downloaded | ❌ 765 failed
# Processed 890/1499 — ✅ 116 downloaded | ❌ 774 failed
# Processed 900/1499 — ✅ 118 downloaded | ❌ 782 failed
# Processed 910/1499 — ✅ 119 downloaded | ❌ 791 failed
# Processed 920/1499 — ✅ 121 downloaded | ❌ 799 failed
# Processed 930/1499 — ✅ 123 downloaded | ❌ 807 failed
# Processed 940/1499 — ✅ 124 downloaded | ❌ 816 failed
# Processed 950/1499 — ✅ 127 downloaded | ❌ 823 failed
# Processed 960/1499 — ✅ 128 downloaded | ❌ 832 failed
# Processed 970/1499 — ✅ 131 downloaded | ❌ 839 failed
# Processed 980/1499 — ✅ 131 downloaded | ❌ 849 failed
# Processed 990/1499 — ✅ 132 downloaded | ❌ 858 failed
# Processed 1000/1499 — ✅ 132 downloaded | ❌ 868 failed
# Processed 1010/1499 — ✅ 133 downloaded | ❌ 877 failed
# Processed 1020/1499 — ✅ 134 downloaded | ❌ 886 failed
# Processed 1030/1499 — ✅ 135 downloaded | ❌ 895 failed
# Processed 1040/1499 — ✅ 136 downloaded | ❌ 904 failed
# Processed 1050/1499 — ✅ 140 downloaded | ❌ 910 failed
# Processed 1060/1499 — ✅ 142 downloaded | ❌ 918 failed
# Processed 1070/1499 — ✅ 142 downloaded | ❌ 928 failed
# Processed 1080/1499 — ✅ 143 downloaded | ❌ 937 failed
# Processed 1090/1499 — ✅ 145 downloaded | ❌ 945 failed
# Processed 1100/1499 — ✅ 145 downloaded | ❌ 955 failed
# Processed 1110/1499 — ✅ 147 downloaded | ❌ 963 failed
# Processed 1120/1499 — ✅ 148 downloaded | ❌ 972 failed
# Processed 1130/1499 — ✅ 151 downloaded | ❌ 979 failed
# Processed 1140/1499 — ✅ 152 downloaded | ❌ 988 failed
# Processed 1150/1499 — ✅ 154 downloaded | ❌ 996 failed
# Processed 1160/1499 — ✅ 156 downloaded | ❌ 1004 failed
# Processed 1170/1499 — ✅ 158 downloaded | ❌ 1012 failed
# Processed 1180/1499 — ✅ 159 downloaded | ❌ 1021 failed
# Processed 1190/1499 — ✅ 159 downloaded | ❌ 1031 failed
# Processed 1200/1499 — ✅ 163 downloaded | ❌ 1037 failed
# Processed 1210/1499 — ✅ 164 downloaded | ❌ 1046 failed
# Processed 1220/1499 — ✅ 165 downloaded | ❌ 1055 failed
# Processed 1230/1499 — ✅ 167 downloaded | ❌ 1063 failed
# Processed 1240/1499 — ✅ 169 downloaded | ❌ 1071 failed
# Processed 1250/1499 — ✅ 170 downloaded | ❌ 1080 failed
# Processed 1260/1499 — ✅ 172 downloaded | ❌ 1088 failed
# Processed 1270/1499 — ✅ 173 downloaded | ❌ 1097 failed
# Processed 1280/1499 — ✅ 174 downloaded | ❌ 1106 failed
# Processed 1290/1499 — ✅ 175 downloaded | ❌ 1115 failed
# Processed 1300/1499 — ✅ 175 downloaded | ❌ 1125 failed
# Processed 1310/1499 — ✅ 176 downloaded | ❌ 1134 failed
# Processed 1320/1499 — ✅ 178 downloaded | ❌ 1142 failed
# Processed 1330/1499 — ✅ 179 downloaded | ❌ 1151 failed
# Processed 1340/1499 — ✅ 180 downloaded | ❌ 1160 failed
# Processed 1350/1499 — ✅ 182 downloaded | ❌ 1168 failed
# Processed 1360/1499 — ✅ 185 downloaded | ❌ 1175 failed
# Processed 1370/1499 — ✅ 186 downloaded | ❌ 1184 failed
# Processed 1380/1499 — ✅ 187 downloaded | ❌ 1193 failed
# Processed 1390/1499 — ✅ 187 downloaded | ❌ 1203 failed
# Processed 1400/1499 — ✅ 188 downloaded | ❌ 1212 failed
# Processed 1410/1499 — ✅ 188 downloaded | ❌ 1222 failed
# Processed 1420/1499 — ✅ 189 downloaded | ❌ 1231 failed
# Processed 1430/1499 — ✅ 190 downloaded | ❌ 1240 failed
# Processed 1440/1499 — ✅ 190 downloaded | ❌ 1250 failed
# Processed 1450/1499 — ✅ 190 downloaded | ❌ 1260 failed
# Processed 1460/1499 — ✅ 191 downloaded | ❌ 1269 failed
# Processed 1470/1499 — ✅ 191 downloaded | ❌ 1279 failed
# Processed 1480/1499 — ✅ 192 downloaded | ❌ 1288 failed
# Processed 1490/1499 — ✅ 193 downloaded | ❌ 1297 failed
#
# 🎉 Done! PDFs saved in folder: papers_1
# ✅ Total successful: 194
# ❌ Total failed: 1305
